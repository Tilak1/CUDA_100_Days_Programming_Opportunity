# %%
from hta.trace_analysis import TraceAnalysis

# Analyze the new traces
#analyzer = TraceAnalysis(trace_dir="/home/tilak/Alinet_optim/inference-optimization-blog-post/part-3")
#analyzer = TraceAnalysis(trace_dir="C:\Tilak\CUDA\cuda_100_days_opportuniyt\Day_13_Deep_Learning_Model_Pre_Optimization_Profiling\train_hta")
analyzer = TraceAnalysis(trace_dir="C:/Tilak/CUDA/cuda_100_days_opportuniyt/Day_13_Deep_Learning_Model_Pre_Optimization_Profiling/train_hta")

#C:\Tilak\CUDA\cuda_100_days_opportuniyt\Day_13_Deep_Learning_Model_Pre_Optimization_Profiling\train_hta

# Get detailed breakdown
temporal_breakdown = analyzer.get_temporal_breakdown()
kernel_breakdown = analyzer.get_gpu_kernel_breakdown()
#kernel_breakdown_df = analyzer.get_gpu_kernel_breakdown()
idle_time = analyzer.get_idle_time_breakdown()

# Print results
print(temporal_breakdown)
print(kernel_breakdown)
# Out:
# Parsed C:/Tilak/CUDA/cuda_100_days_opportuniyt/Day_13_Deep_Learning_Model_Pre_Optimization_Profiling/train_hta\hta_v2_train.pt.trace.json time = 7.75 seconds
# Rounding down ns resolution events due to issue with events overlapping. ts dtype = float64, dur dtype = float64.Please see https://github.com/pytorch/pytorch/pull/122425
# Parsed C:/Tilak/CUDA/cuda_100_days_opportuniyt/Day_13_Deep_Learning_Model_Pre_Optimization_Profiling/train_hta\hta_v2_train.pt.trace.json backend=ParserBackend.JSON in 19.09 seconds; current PID:8548
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 6
#       1 from hta.trace_analysis import TraceAnalysis
#       3 # Analyze the new traces
#       4 #analyzer = TraceAnalysis(trace_dir="/home/tilak/Alinet_optim/inference-optimization-blog-post/part-3")
#       5 #analyzer = TraceAnalysis(trace_dir="C:\Tilak\CUDA\cuda_100_days_opportuniyt\Day_13_Deep_Learning_Model_Pre_Optimization_Profiling\train_hta")
# ----> 6 analyzer = TraceAnalysis(trace_dir="C:/Tilak/CUDA/cuda_100_days_opportuniyt/Day_13_Deep_Learning_Model_Pre_Optimization_Profiling/train_hta")
#       8 #C:\Tilak\CUDA\cuda_100_days_opportuniyt\Day_13_Deep_Learning_Model_Pre_Optimization_Profiling\train_hta
#       9
#      10 # Get detailed breakdown
#      11 temporal_breakdown = analyzer.get_temporal_breakdown()
#
# File C:\Tilak\CUDA\venv_webpdf\Lib\site-packages\hta\trace_analysis.py:38, in TraceAnalysis.__init__(self, trace_files, trace_dir, include_last_profiler_step)
#      31 def __init__(
#      32     self,
#      33     trace_files: Optional[Dict[int, str]] = None,
#      34     trace_dir: str = DEFAULT_TRACE_DIR,
#      35     include_last_profiler_step: Optional[bool] = False,
#      36 ):
#      37     self.t = Trace(trace_files, trace_dir)
# ---> 38     self.t.load_traces(include_last_profiler_step)
#      39     assert self.t.is_parsed is True
#
# File C:\Tilak\CUDA\venv_webpdf\Lib\site-packages\hta\common\trace.py:414, in Trace.load_traces(self, include_last_profiler_step, use_multiprocessing, use_memory_profiling)
#     412     logger.warning("Traces are already parsed and loaded!")
#     413     return
# --> 414 self.parse_traces(
#     415     use_multiprocessing=use_multiprocessing,
#     416     use_memory_profiling=use_memory_profiling,
#     417 )
#     418 self.align_and_filter_trace(include_last_profiler_step)
#     419 for rank, df in self.traces.items():
#
# File C:\Tilak\CUDA\venv_webpdf\Lib\site-packages\hta\common\trace.py:547, in Trace.parse_traces(self, max_ranks, use_multiprocessing, use_memory_profiling)
#     545 if len(ranks) > 0:
#     546     use_multiprocessing = use_multiprocessing and len(ranks) > 1
# --> 547     self.parse_multiple_ranks(ranks, use_multiprocessing, use_memory_profiling)
#     549     self.is_parsed = True
#     550 else:
#
# File C:\Tilak\CUDA\venv_webpdf\Lib\site-packages\hta\common\trace.py:473, in Trace.parse_multiple_ranks(self, ranks, use_multiprocessing, use_memory_profiling)
#     471 for rank in ranks:
#     472     logger.debug(f"parsing trace for rank-{rank}")
# --> 473     result = parse_trace_file(self.trace_files[rank], self.parser_config)
#     474     self.meta_data[rank], self.traces[rank], local_symbol_tables[rank] = (
#     475         result[0],
#     476         result[1],
#     477         result[2],
#     478     )
#     479     self.symbol_table.add_symbols(local_symbol_tables[rank].get_sym_table())
#
# File C:\Tilak\CUDA\venv_webpdf\Lib\site-packages\hta\common\trace.py:253, in parse_trace_file(trace_file_path, cfg)
#     250 # add fwd bwd links between CPU ops
#     251 add_fwd_bwd_links(df)
# --> 253 df = transform_correlation_to_index(df, local_symbol_table)
#     255 add_iteration(df, local_symbol_table)
#     256 df["end"] = df["ts"] + df["dur"]
#
# File C:\Tilak\CUDA\venv_webpdf\Lib\site-packages\hta\common\trace.py:127, in transform_correlation_to_index(df, symbol_table)
#     122 on_gpu = GPUKernelFilter()(corr_df, symbol_table)
#     124 # We only need to merge once.
#     125 # index_x --> index_y will be cpu to gpu mapping
#     126 # index_y --> index_x will be gpu to cpu mapping
# --> 127 merged = on_cpu.merge(on_gpu, on="correlation", how="inner")
#     128 df.loc[merged["index_x"], "index_correlation"] = merged["index_y"].values
#     129 df.loc[merged["index_y"], "index_correlation"] = merged["index_x"].values
#
# File C:\Tilak\CUDA\venv_webpdf\Lib\site-packages\pandas\core\frame.py:10839, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10820 @Substitution("")
#   10821 @Appender(_merge_doc, indents=2)
#   10822 def merge(
#    (...)  10835     validate: MergeValidate | None = None,
#   10836 ) -> DataFrame:
#   10837     from pandas.core.reshape.merge import merge
# > 10839     return merge(
#   10840         self,
#   10841         right,
#   10842         how=how,
#   10843         on=on,
#   10844         left_on=left_on,
#   10845         right_on=right_on,
#   10846         left_index=left_index,
#   10847         right_index=right_index,
#   10848         sort=sort,
#   10849         suffixes=suffixes,
#   10850         copy=copy,
#   10851         indicator=indicator,
#   10852         validate=validate,
#   10853     )
#
# File C:\Tilak\CUDA\venv_webpdf\Lib\site-packages\pandas\core\reshape\merge.py:184, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     169 else:
#     170     op = _MergeOperation(
#     171         left_df,
#     172         right_df,
#    (...)    182         validate=validate,
#     183     )
# --> 184     return op.get_result(copy=copy)
#
# File C:\Tilak\CUDA\venv_webpdf\Lib\site-packages\pandas\core\reshape\merge.py:886, in _MergeOperation.get_result(self, copy)
#     883 if self.indicator:
#     884     self.left, self.right = self._indicator_pre_merge(self.left, self.right)
# --> 886 join_index, left_indexer, right_indexer = self._get_join_info()
#     888 result = self._reindex_and_concat(
#     889     join_index, left_indexer, right_indexer, copy=copy
#     890 )
#     891 result = result.__finalize__(self, method=self._merge_type)
#
# File C:\Tilak\CUDA\venv_webpdf\Lib\site-packages\pandas\core\reshape\merge.py:1151, in _MergeOperation._get_join_info(self)
#    1147     join_index, right_indexer, left_indexer = _left_join_on_index(
#    1148         right_ax, left_ax, self.right_join_keys, sort=self.sort
#    1149     )
#    1150 else:
# -> 1151     (left_indexer, right_indexer) = self._get_join_indexers()
#    1153     if self.right_index:
#    1154         if len(self.left) > 0:
#
# File C:\Tilak\CUDA\venv_webpdf\Lib\site-packages\pandas\core\reshape\merge.py:1125, in _MergeOperation._get_join_indexers(self)
#    1123 # make mypy happy
#    1124 assert self.how != "asof"
# -> 1125 return get_join_indexers(
#    1126     self.left_join_keys, self.right_join_keys, sort=self.sort, how=self.how
#    1127 )
#
# File C:\Tilak\CUDA\venv_webpdf\Lib\site-packages\pandas\core\reshape\merge.py:1759, in get_join_indexers(left_keys, right_keys, sort, how)
#    1757     _, lidx, ridx = left.join(right, how=how, return_indexers=True, sort=sort)
#    1758 else:
# -> 1759     lidx, ridx = get_join_indexers_non_unique(
#    1760         left._values, right._values, sort, how
#    1761     )
#    1763 if lidx is not None and is_range_indexer(lidx, len(left)):
#    1764     lidx = None
#
# File C:\Tilak\CUDA\venv_webpdf\Lib\site-packages\pandas\core\reshape\merge.py:1793, in get_join_indexers_non_unique(left, right, sort, how)
#    1770 def get_join_indexers_non_unique(
#    1771     left: ArrayLike,
#    1772     right: ArrayLike,
#    1773     sort: bool = False,
#    1774     how: JoinHow = "inner",
#    1775 ) -> tuple[npt.NDArray[np.intp], npt.NDArray[np.intp]]:
#    1776     """
#    1777     Get join indexers for left and right.
#    1778
#    (...)   1791         Indexer into right.
#    1792     """
# -> 1793     lkey, rkey, count = _factorize_keys(left, right, sort=sort)
#    1794     if how == "left":
#    1795         lidx, ridx = libjoin.left_outer_join(lkey, rkey, count, sort=sort)
#
# File C:\Tilak\CUDA\venv_webpdf\Lib\site-packages\pandas\core\reshape\merge.py:2560, in _factorize_keys(lk, rk, sort)
#    2553     rlab = rizer.factorize(
#    2554         rk.to_numpy(na_value=1, dtype=lk.dtype.numpy_dtype), mask=rk.isna()
#    2555     )
#    2556 else:
#    2557     # Argument 1 to "factorize" of "ObjectFactorizer" has incompatible type
#    2558     # "Union[ndarray[Any, dtype[signedinteger[_64Bit]]],
#    2559     # ndarray[Any, dtype[object_]]]"; expected "ndarray[Any, dtype[object_]]"
# -> 2560     llab = rizer.factorize(lk)  # type: ignore[arg-type]
#    2561     rlab = rizer.factorize(rk)  # type: ignore[arg-type]
#    2562 assert llab.dtype == np.dtype(np.intp), llab.dtype
#
# File pandas/_libs/hashtable_class_helper.pxi:3045, in pandas._libs.hashtable.Int64Factorizer.factorize()
#
# ValueError: Buffer dtype mismatch, expected 'const int64_t' but got 'int'
